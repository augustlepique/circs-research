# %% [markdown]
# # Converting .txt files into .csv files

# %% [markdown]
# The preliminary storm reports are only available as manual .txt files. The goal of this notebook is to figure out how to convert the .txt files into .csv files. The files have already been converted now so no need to run these cells

# %%
import csv
import os

# %% [markdown]
# ### Here I experiment with converting one .txt file into a .csv file

# %%
infile = "040320_rpts_hail.txt"     # tab-delimited raw file
outfile = "040320_rpts_hail.csv"    # output CSV

with open(infile, "r", encoding="utf-8") as f:
    lines = [ln.rstrip("\n") for ln in f if ln.strip()]

header = lines[0].split("\t")

# Find where Lat/Lon live
try:
    lat_i = header.index("Lat")
    lon_i = header.index("Lon")
except ValueError as e:
    raise ValueError("Could not find 'Lat' and/or 'Lon' columns in header.") from e

rows_out = []

for ln in lines[1:]:
    parts = ln.split("\t")

    # If extra tabs sneak into Comments, fold them back into the last column
    if len(parts) > len(header):
        parts = parts[:len(header) - 1] + [" ".join(parts[len(header) - 1:])]

    # Skip malformed lines
    if len(parts) != len(header):
        continue

    # Convert Lat/Lon in place
    lat_str = parts[lat_i].strip()
    lon_str = parts[lon_i].strip()

    try:
        parts[lat_i] = f"{float(lat_str)/100.0:.2f}"
    except ValueError:
        pass  # leave as-is if not numeric

    try:
        parts[lon_i] = f"{-float(lon_str)/100.0:.2f}"  # western hemisphere -> negative
    except ValueError:
        pass  # leave as-is if not numeric

    rows_out.append(parts)

with open(outfile, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(rows_out)

print(f"Wrote {len(rows_out)} rows to {outfile}")
# Out:
# Wrote 71 rows to 040320_rpts_hail.csv

# %% [markdown]
# ### Trying to do the same thing, but looping through all txt files in a folder

# %%
import os

input_dir = "/home1/lepique/stormreports_99_txt/"
output_dir = "/home1/lepique/storm_reports/stormreports_99"

os.makedirs(output_dir, exist_ok=True)

print("Input dir:", input_dir)
print("Output dir:", output_dir)
# Out:
# Input dir: /home1/lepique/stormreports_99_txt/
# Output dir: /home1/lepique/storm_reports/stormreports_99

# %%
all_files = os.listdir(input_dir)
print("All files:", all_files[:5])  # printing the first 5
# Out:
# All files: ['991204_rpts_hail.txt', '000329_rpts_torn.txt', '000315_rpts_wind.txt', '000307_rpts_torn.txt', '000302_rpts_wind.txt']

# %%
for filename in all_files:
    print(filename)
# Out:
# 991204_rpts_hail.txt
# 000329_rpts_torn.txt
# 000315_rpts_wind.txt
# 000307_rpts_torn.txt
# 000302_rpts_wind.txt
# 000310_rpts_torn.txt
# 000320_rpts_hail.txt
# 000328_rpts_wind.txt
# 000324_rpts_hail.txt
# 000306_rpts_wind.txt
# 000314_rpts_torn.txt
# 000311_rpts_wind.txt
# 000303_rpts_torn.txt
# 000222_rpts_wind.txt
# 000227_rpts_torn.txt
# 000217_rpts_hail.txt
# 000104_rpts_wind.txt
# 000213_rpts_hail.txt
# 000226_rpts_wind.txt
# 000103_rpts_wind.txt
# 000218_rpts_wind.txt
# 000214_rpts_hail.txt
# 000224_rpts_torn.txt
# 000221_rpts_wind.txt
# 000110_rpts_wind.txt
# 000229_rpts_hail.txt
# 000225_rpts_wind.txt
# 000323_rpts_hail.txt
# 000316_rpts_wind.txt
# 991203_rpts_hail.txt
# 000309_rpts_hail.txt
# 000330_rpts_hail.txt
# 000305_rpts_wind.txt
# 000327_rpts_hail.txt
# 000314_rpts_hail.txt
# 000303_rpts_hail.txt
# 991209_rpts_hail.txt
# 000321_rpts_wind.txt
# 000318_rpts_wind.txt
# 000325_rpts_wind.txt
# 000307_rpts_hail.txt
# 000310_rpts_hail.txt
# 991204_rpts_torn.txt
# 000329_rpts_hail.txt
# 000213_rpts_torn.txt
# 000223_rpts_hail.txt
# 000109_rpts_wind.txt
# 000217_rpts_torn.txt
# 000112_rpts_hail.txt
# 000207_rpts_torn.txt
# 000210_rpts_torn.txt
# 000102_rpts_hail.txt
# 000229_rpts_torn.txt
# 000214_rpts_torn.txt
# 000224_rpts_hail.txt
# 000211_rpts_wind.txt
# 000124_rpts_wind.txt
# 000330_rpts_torn.txt
# 000323_rpts_torn.txt
# 991219_rpts_hail.txt
# 000331_rpts_wind.txt
# 000304_rpts_hail.txt
# 991202_rpts_wind.txt
# 000308_rpts_wind.txt
# 000229_rpts_wind.txt
# 000225_rpts_hail.txt
# 000218_rpts_hail.txt
# 000103_rpts_hail.txt
# 000214_rpts_wind.txt
# 000309_rpts_wind.txt
# 991203_rpts_wind.txt
# 000327_rpts_wind.txt
# 000322_rpts_torn.txt
# 000330_rpts_wind.txt
# 000308_rpts_torn.txt
# 991202_rpts_torn.txt
# 000316_rpts_hail.txt
# 000301_rpts_hail.txt
# 000331_rpts_torn.txt
# 000323_rpts_wind.txt
# 991217_rpts_wind.txt
# 000321_rpts_torn.txt
# 000311_rpts_hail.txt
# 991213_rpts_wind.txt
# 000319_rpts_wind.txt
# 991204_rpts_wind.txt
# 991208_rpts_hail.txt
# 000302_rpts_hail.txt
# 000315_rpts_hail.txt
# 000226_rpts_hail.txt
# 000213_rpts_wind.txt
# 000217_rpts_wind.txt
# 000222_rpts_hail.txt
# 000211_rpts_hail.txt
# 000224_rpts_wind.txt
# 000218_rpts_torn.txt
# 000103_rpts_torn.txt
# 000111_rpts_wind.txt
# 000225_rpts_torn.txt
# 000102_rpts_wind.txt
# 000316_rpts_torn.txt
# 000331_rpts_hail.txt
# 000308_rpts_hail.txt
# 991202_rpts_hail.txt
# 000322_rpts_hail.txt
# 000310_rpts_wind.txt
# 000307_rpts_wind.txt
# 000315_rpts_torn.txt
# 000325_rpts_hail.txt
# 000329_rpts_wind.txt
# 000321_rpts_hail.txt
# 991209_rpts_wind.txt
# 000303_rpts_wind.txt
# 000311_rpts_torn.txt
# 000314_rpts_wind.txt
# 000328_rpts_torn.txt
# 000318_rpts_hail.txt
# 000109_rpts_hail.txt
# 000227_rpts_wind.txt
# 000222_rpts_torn.txt
# 000216_rpts_hail.txt
# 000123_rpts_hail.txt
# 000116_rpts_wind.txt
# 000104_rpts_torn.txt

# %%
# Filter for only .txt files
txt_files = [f for f in all_files if f.endswith(".txt")]
for filename in txt_files:
    input_path = os.path.join(input_dir, filename)
    output_path = os.path.join(output_dir, filename.replace(".txt", ".csv"))
    print(input_path)
    print(output_path)
# Out:
# /home1/lepique/stormreports_99_txt/991204_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/991204_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000329_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000329_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000315_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000315_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000307_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000307_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000302_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000302_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000310_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000310_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000320_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000320_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000328_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000328_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000324_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000324_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000306_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000306_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000314_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000314_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000311_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000311_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000303_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000303_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000222_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000222_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000227_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000227_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000217_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000217_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000104_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000104_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000213_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000213_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000226_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000226_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000103_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000103_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000218_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000218_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000214_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000214_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000224_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000224_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000221_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000221_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000110_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000110_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000229_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000229_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000225_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000225_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000323_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000323_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000316_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000316_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/991203_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/991203_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000309_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000309_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000330_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000330_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000305_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000305_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000327_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000327_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000314_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000314_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000303_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000303_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/991209_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/991209_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000321_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000321_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000318_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000318_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000325_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000325_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000307_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000307_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000310_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000310_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/991204_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/991204_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000329_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000329_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000213_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000213_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000223_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000223_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000109_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000109_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000217_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000217_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000112_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000112_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000207_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000207_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000210_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000210_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000102_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000102_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000229_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000229_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000214_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000214_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000224_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000224_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000211_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000211_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000124_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000124_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000330_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000330_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000323_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000323_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/991219_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/991219_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000331_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000331_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000304_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000304_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/991202_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/991202_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000308_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000308_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000229_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000229_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000225_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000225_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000218_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000218_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000103_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000103_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000214_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000214_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000309_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000309_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/991203_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/991203_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000327_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000327_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000322_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000322_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000330_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000330_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000308_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000308_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/991202_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/991202_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000316_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000316_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000301_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000301_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000331_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000331_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000323_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000323_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/991217_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/991217_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000321_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000321_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000311_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000311_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/991213_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/991213_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000319_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000319_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/991204_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/991204_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/991208_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/991208_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000302_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000302_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000315_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000315_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000226_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000226_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000213_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000213_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000217_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000217_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000222_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000222_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000211_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000211_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000224_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000224_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000218_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000218_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000103_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000103_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000111_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000111_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000225_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000225_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000102_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000102_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000316_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000316_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000331_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000331_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000308_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000308_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/991202_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/991202_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000322_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000322_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000310_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000310_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000307_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000307_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000315_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000315_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000325_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000325_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000329_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000329_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000321_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000321_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/991209_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/991209_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000303_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000303_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000311_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000311_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000314_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000314_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000328_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000328_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000318_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000318_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000109_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000109_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000227_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000227_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000222_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000222_rpts_torn.csv
# /home1/lepique/stormreports_99_txt/000216_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000216_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000123_rpts_hail.txt
# /home1/lepique/storm_reports/stormreports_99/000123_rpts_hail.csv
# /home1/lepique/stormreports_99_txt/000116_rpts_wind.txt
# /home1/lepique/storm_reports/stormreports_99/000116_rpts_wind.csv
# /home1/lepique/stormreports_99_txt/000104_rpts_torn.txt
# /home1/lepique/storm_reports/stormreports_99/000104_rpts_torn.csv

# %%
files_written=0

for filename in txt_files:
    input_path = os.path.join(input_dir, filename)
    output_path = os.path.join(output_dir, filename.replace(".txt", ".csv"))
    #print(input_path)
    #print(output_path)
    
    
    with open(input_path, "r", encoding="utf-8") as f:
        lines = [ln.rstrip("\n") for ln in f if ln.strip()]

        header = lines[0].split("\t")

    ### Find where Lat/Lon live
    try:
        lat_i = header.index("Lat")
        lon_i = header.index("Lon")
    except ValueError as e:
        raise ValueError("Could not find 'Lat' and/or 'Lon' columns in header.") from e

    rows_out = []

    for ln in lines[1:]:
        parts = ln.split("\t")

        #If extra tabs get into comments, fold them back into last column
        if len(parts) > len(header):
            parts = parts[:len(header)-1] + [" ".join(parts[len(header) - 1:])]

        #Skip malformed lines
        if len(parts) != len(header):
            continue

        #Convert Lat/Lon in place
        lat_str = parts[lat_i].strip()
        lon_str = parts[lon_i].strip()

        try:
            parts[lat_i] = f"{float(lat_str)/100.0:.2f}"
        except ValueError:
            pass #leave as-is if not numeric

        try:
            parts[lon_i] = f"{-float(lon_str)/100.0:.2f}" #western hemisphere -> negative
        except ValueError:
            pass #leave as is if not numeric
        
        rows_out.append(parts)

        

    with open(output_path, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(header)
        writer.writerows(rows_out)

    files_written += 1

print(f"Wrote {files_written} files")
# Out:
# Wrote 124 files
